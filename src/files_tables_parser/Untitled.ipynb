# %%
import tabula
import pandas as pd
from tabula import read_pdf
import numpy

# %%
p = r"C:\Scripts\Covid-19-data\src\israeli_health_ministry_telegram\telegram_files\2020-04-09_חולים_ביישובים_מעל_5,000_╙в∙в╘в▒в≥в².pdf"

# %%
data_df = read_pdf(input_path=p,
                           # output_format="dataframe", 
                           pages="all",
                           stream=True,
                          silent=True)

# %%
data_df[3]
# Out:
#    אוכלוסי2ה 9נכ7ו,ן 7ל 2018- אבו גוש ישוב  מספר 1חולים Unnamed: 0
# 0                    אבו רוביעה (שבט)8,446            1        Abc
# 1                                בענה8,355            1        Abc
# 2                              בת חפר5,124            1        Abc
# 3                         דיר אל-אסד12,435            1        Abc
# 4                                 זמר6,926            1        Abc
# 5                              חורפיש6,288            1        Abc
# 6                         טובא-זנגריה6,648            1        Abc
# 7                              ירוחם10,126            1        Abc
# 8                          מג'דל שמס11,089            1        Abc
# 9                  מסעודין אל-עזאזמה16,644            1        Abc
# 10                               נחף13,167            1        Abc
# 11                             עספיא12,141            1        Abc
# 12                             עראבה25,876            1        Abc
# ...
